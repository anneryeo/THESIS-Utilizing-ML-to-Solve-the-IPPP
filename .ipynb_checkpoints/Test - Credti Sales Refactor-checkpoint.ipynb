# %% [markdown]
# # Importation of libraries

# %%
# Standard libraries
import pandas as pd
import numpy as np

# Non-standard Libaries
from DataLoaders.bad_debts import BadDebtsExpense

from FeatureEngineering.credit_sales import CreditSales
from FeatureEngineering.days_sales_outstanding import DSO
from FeatureEngineering.consecutive_years import get_consecutive_years

from Analysis.enrollment_statistics import enrollment_statistics

# %% [markdown]
# # B. Loading of datasets

# %% [markdown]
# ## 1. Revenues

# %%
df_revenues = pd.read_excel(r"Database\revenues_pseudonymized.xlsx")

# %%
df_revenues
# Out:
#        entry_number entry_date   due_date  school_year  \
# 0                 0 2025-10-13 2025-10-13         2014
# 1                 1 2016-01-01 2016-01-01         2016
# 2                 2 2016-01-01 2016-01-01         2016
# 3                 3 2016-01-01 2016-01-01         2016
# 4                 4 2016-01-01 2016-01-01         2016
# ...             ...        ...        ...          ...
# 50149         52878 2026-01-21 2026-01-21         2026
# 50150         52879 2026-01-21 2026-07-11         2026
# 50151         52880 2026-01-21 2026-07-11         2026
# 50152         52881 2026-01-21 2026-07-11         2026
# 50153         52882 2026-01-21 2026-01-21         2026
#
#       student_id_pseudonimized              category_name  \
# 0                     9XBPS6GQ                   Form 137
# 1                     QCNXOF71               Back Account
# 2                     UFN5RBCA               Back Account
# 3                     CATF26JR               Back Account
# 4                     TE11Z2LJ               Back Account
# ...                        ...                        ...
# 50149                 KX9K7HHC                     G03-OF
# 50150                 7TIF6WOZ                   G04-A-UE
# 50151                 7TIF6WOZ  Discount - Early Enrollee
# 50152                 7TIF6WOZ        Discount - Pastoral
# 50153                 7TIF6WOZ                     G04-OF
#
#       discount_refund_applied_to  amount_due  amount_paid    account_name  \
# 0                            NaN       150.0        150.0          G-Cash
# 1                            NaN      3524.0          0.0  Not Applicable
# 2                            NaN      9831.0          0.0  Not Applicable
# 3                            NaN      9240.0          0.0  Not Applicable
# 4                            NaN      5886.0          0.0  Not Applicable
# ...                          ...         ...          ...             ...
# 50149                        NaN     16400.0      16400.0            Cash
# 50150                        NaN     30800.0      13860.0            Cash
# 50151                   G04-A-UE     -3080.0          0.0  Not Applicable
# 50152                   G04-A-UE    -13860.0          0.0  Not Applicable
# 50153                        NaN     17900.0      17900.0            Cash
#
#        receivables
# 0              0.0
# 1           3524.0
# 2           9831.0
# 3           9240.0
# 4           5886.0
# ...            ...
# 50149          0.0
# 50150      16940.0
# 50151      -3080.0
# 50152     -13860.0
# 50153          0.0
#
# [50154 rows x 11 columns]

# %% [markdown]
# ## 2. Credit Sales

# %%
import time

# %%
start = time.time()
cs = CreditSales(df_revenues)

end = time.time()
print(f"Execution time: {end - start:.6f} seconds")

df_truth = cs.show_data()
df_truth = df_truth.groupby(['school_year', 'student_id_pseudonimized', 'category_name']).sum(numeric_only=True)
# Out:
# Execution time: 0.799764 seconds

# %%
from FeatureEngineering.credit_sales_multiple_backup import CreditSales as CreditSalesOptimized

start = time.time()

cs_brute = CreditSalesOptimized(df_revenues)

end = time.time()
print(f"Execution time: {end - start:.6f} seconds")
# Out:
# Single due date records: 7371
# Multiple due date records: 2748
# Execution time: 18.456008 seconds

# %%
from FeatureEngineering.credit_sales_multiple import CreditSales as CreditSalesOptimized

start = time.time()

cs_opti = CreditSalesOptimized(df_revenues)

end = time.time()
print(f"Execution time: {end - start:.6f} seconds")
# Out:
# Single due date records: 9800
# Multiple due date records: 261
# Execution time: 5.828010 seconds

# %%
df_truth
# Out:
#                                                     gross_receivables  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account              9240.0
#             LI5DFHZ5                 Back Account              5650.0
#             QCNXOF71                 Back Account              3524.0
#             TE11Z2LJ                 Back Account              5886.0
#             UFN5RBCA                 Back Account              9831.0
# ...                                                               ...
# 2026        O9S9VFIM                 G04-Books                 6260.0
#             XO7E9JLP                 G09-OF                     800.0
#             YMJ3L6X6                 G08-B-2nd                 5200.0
#                                      G08-OF-2nd                6267.0
#                                      G08-OF-3rd                6266.0
#
#                                                     amount_discounted  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account                 0.0
#             LI5DFHZ5                 Back Account                 0.0
#             QCNXOF71                 Back Account                 0.0
#             TE11Z2LJ                 Back Account                 0.0
#             UFN5RBCA                 Back Account                 0.0
# ...                                                               ...
# 2026        O9S9VFIM                 G04-Books                 -700.0
#             XO7E9JLP                 G09-OF                       0.0
#             YMJ3L6X6                 G08-B-2nd                    0.0
#                                      G08-OF-2nd                   0.0
#                                      G08-OF-3rd                   0.0
#
#                                                     adjustments  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account           0.0
#             LI5DFHZ5                 Back Account           0.0
#             QCNXOF71                 Back Account           0.0
#             TE11Z2LJ                 Back Account           0.0
#             UFN5RBCA                 Back Account           0.0
# ...                                                         ...
# 2026        O9S9VFIM                 G04-Books              0.0
#             XO7E9JLP                 G09-OF                 0.0
#             YMJ3L6X6                 G08-B-2nd              0.0
#                                      G08-OF-2nd             0.0
#                                      G08-OF-3rd             0.0
#
#                                                     credit_sale_amount  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account               9240.0
#             LI5DFHZ5                 Back Account               5650.0
#             QCNXOF71                 Back Account               3524.0
#             TE11Z2LJ                 Back Account               5886.0
#             UFN5RBCA                 Back Account               9831.0
# ...                                                                ...
# 2026        O9S9VFIM                 G04-Books                  5560.0
#             XO7E9JLP                 G09-OF                      800.0
#             YMJ3L6X6                 G08-B-2nd                  5200.0
#                                      G08-OF-2nd                 6267.0
#                                      G08-OF-3rd                 6266.0
#
#                                                     prepayments  30_days  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account           0.0      0.0
#             LI5DFHZ5                 Back Account           0.0      0.0
#             QCNXOF71                 Back Account           0.0      0.0
#             TE11Z2LJ                 Back Account           0.0      0.0
#             UFN5RBCA                 Back Account           0.0      0.0
# ...                                                         ...      ...
# 2026        O9S9VFIM                 G04-Books              0.0      0.0
#             XO7E9JLP                 G09-OF               800.0      0.0
#             YMJ3L6X6                 G08-B-2nd              0.0      0.0
#                                      G08-OF-2nd             0.0      0.0
#                                      G08-OF-3rd             0.0      0.0
#
#                                                     60_days  90_days  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account       0.0      0.0
#             LI5DFHZ5                 Back Account       0.0      0.0
#             QCNXOF71                 Back Account       0.0      0.0
#             TE11Z2LJ                 Back Account       0.0      0.0
#             UFN5RBCA                 Back Account       0.0      0.0
# ...                                                     ...      ...
# 2026        O9S9VFIM                 G04-Books          0.0      0.0
#             XO7E9JLP                 G09-OF             0.0      0.0
#             YMJ3L6X6                 G08-B-2nd          0.0      0.0
#                                      G08-OF-2nd         0.0      0.0
#                                      G08-OF-3rd         0.0      0.0
#
#                                                     120_days  150_days  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account        0.0       0.0
#             LI5DFHZ5                 Back Account        0.0       0.0
#             QCNXOF71                 Back Account        0.0       0.0
#             TE11Z2LJ                 Back Account        0.0       0.0
#             UFN5RBCA                 Back Account        0.0       0.0
# ...                                                      ...       ...
# 2026        O9S9VFIM                 G04-Books           0.0       0.0
#             XO7E9JLP                 G09-OF              0.0       0.0
#             YMJ3L6X6                 G08-B-2nd           0.0       0.0
#                                      G08-OF-2nd          0.0       0.0
#                                      G08-OF-3rd          0.0       0.0
#
#                                                     180_days  180_above  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account        0.0     9240.0
#             LI5DFHZ5                 Back Account        0.0     5650.0
#             QCNXOF71                 Back Account        0.0     3524.0
#             TE11Z2LJ                 Back Account        0.0     5886.0
#             UFN5RBCA                 Back Account        0.0     9831.0
# ...                                                      ...        ...
# 2026        O9S9VFIM                 G04-Books           0.0        0.0
#             XO7E9JLP                 G09-OF              0.0        0.0
#             YMJ3L6X6                 G08-B-2nd           0.0        0.0
#                                      G08-OF-2nd          0.0        0.0
#                                      G08-OF-3rd          0.0        0.0
#
#                                                     total_payments  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account           9240.0
#             LI5DFHZ5                 Back Account           5650.0
#             QCNXOF71                 Back Account           3524.0
#             TE11Z2LJ                 Back Account           5886.0
#             UFN5RBCA                 Back Account           9831.0
# ...                                                            ...
# 2026        O9S9VFIM                 G04-Books                 0.0
#             XO7E9JLP                 G09-OF                  800.0
#             YMJ3L6X6                 G08-B-2nd                 0.0
#                                      G08-OF-2nd                0.0
#                                      G08-OF-3rd                0.0
#
#                                                     adjusted_credit_amount  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account                   9240.0
#             LI5DFHZ5                 Back Account                   5650.0
#             QCNXOF71                 Back Account                   3524.0
#             TE11Z2LJ                 Back Account                   5886.0
#             UFN5RBCA                 Back Account                   9831.0
# ...                                                                    ...
# 2026        O9S9VFIM                 G04-Books                      5560.0
#             XO7E9JLP                 G09-OF                            0.0
#             YMJ3L6X6                 G08-B-2nd                      5200.0
#                                      G08-OF-2nd                     6267.0
#                                      G08-OF-3rd                     6266.0
#
#                                                     net_receivables
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account               0.0
#             LI5DFHZ5                 Back Account               0.0
#             QCNXOF71                 Back Account               0.0
#             TE11Z2LJ                 Back Account               0.0
#             UFN5RBCA                 Back Account               0.0
# ...                                                             ...
# 2026        O9S9VFIM                 G04-Books               5560.0
#             XO7E9JLP                 G09-OF                     0.0
#             YMJ3L6X6                 G08-B-2nd               5200.0
#                                      G08-OF-2nd              6267.0
#                                      G08-OF-3rd              6266.0
#
# [9886 rows x 15 columns]

# %%
df_brute = cs_brute.show_data()
df_brute = df_brute.groupby(['school_year', 'student_id_pseudonimized', 'category_name']).sum(numeric_only=True)

# %%
df_test_opti = cs_opti.show_data()
df_test_opti.to_excel("credit_sales_test.xlsx", index=False)
df_test_opti = df_test_opti.groupby(['school_year', 'student_id_pseudonimized', 'category_name']).sum(numeric_only=True)

# %%
print(f"Truth : {df_truth.shape[0]}")
print(f"Brute : {df_brute.shape[0]}")
print(f"Test  : {df_test_opti.shape[0]}")
# Out:
# Truth : 9886
# Brute : 9884
# Test  : 9884

# %%
print(f"Truth : {df_truth.amount_discounted.sum()}")
print(f"Brute : {df_brute.amount_discounted.sum()}")
print(f"Test  : {df_test_opti.amount_discounted.sum()}")
# Out:
# Truth : -664521.25
# Brute : -664300.25
# Test  : -664300.25

# %%
print(f"Truth : {df_truth.adjustments.sum()}")
print(f"Brute : {df_brute.adjustments.sum()}")
print(f"Test  : {df_test_opti.adjustments.sum()}")
# Out:
# Truth : -12799.75
# Brute : -12799.75
# Test  : -12799.75

# %%
print(f"Truth : {df_truth.total_payments.sum()}")
print(f"Brute : {df_brute.total_payments.sum()}")
print(f"Test  : {df_test_opti.total_payments.sum()}")
# Out:
# Truth : 40521535.25
# Brute : 40514835.25
# Test  : 40514835.25

# %%
df_test_opti
# Out:
#                                                     gross_receivables  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account              9240.0
#             LI5DFHZ5                 Back Account              5650.0
#             QCNXOF71                 Back Account              3524.0
#             TE11Z2LJ                 Back Account              5886.0
#             UFN5RBCA                 Back Account              9831.0
# ...                                                               ...
# 2026        O9S9VFIM                 G04-Books                 6260.0
#             XO7E9JLP                 G09-OF                     800.0
#             YMJ3L6X6                 G08-B-2nd                 5200.0
#                                      G08-OF-2nd                6267.0
#                                      G08-OF-3rd                6266.0
#
#                                                     amount_discounted  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account                 0.0
#             LI5DFHZ5                 Back Account                 0.0
#             QCNXOF71                 Back Account                 0.0
#             TE11Z2LJ                 Back Account                 0.0
#             UFN5RBCA                 Back Account                 0.0
# ...                                                               ...
# 2026        O9S9VFIM                 G04-Books                 -700.0
#             XO7E9JLP                 G09-OF                       0.0
#             YMJ3L6X6                 G08-B-2nd                    0.0
#                                      G08-OF-2nd                   0.0
#                                      G08-OF-3rd                   0.0
#
#                                                     adjustments  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account           0.0
#             LI5DFHZ5                 Back Account           0.0
#             QCNXOF71                 Back Account           0.0
#             TE11Z2LJ                 Back Account           0.0
#             UFN5RBCA                 Back Account           0.0
# ...                                                         ...
# 2026        O9S9VFIM                 G04-Books              0.0
#             XO7E9JLP                 G09-OF                 0.0
#             YMJ3L6X6                 G08-B-2nd              0.0
#                                      G08-OF-2nd             0.0
#                                      G08-OF-3rd             0.0
#
#                                                     credit_sale_amount  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account               9240.0
#             LI5DFHZ5                 Back Account               5650.0
#             QCNXOF71                 Back Account               3524.0
#             TE11Z2LJ                 Back Account               5886.0
#             UFN5RBCA                 Back Account               9831.0
# ...                                                                ...
# 2026        O9S9VFIM                 G04-Books                  5560.0
#             XO7E9JLP                 G09-OF                      800.0
#             YMJ3L6X6                 G08-B-2nd                  5200.0
#                                      G08-OF-2nd                 6267.0
#                                      G08-OF-3rd                 6266.0
#
#                                                     prepayments  30_days  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account           0.0      0.0
#             LI5DFHZ5                 Back Account           0.0      0.0
#             QCNXOF71                 Back Account           0.0      0.0
#             TE11Z2LJ                 Back Account           0.0      0.0
#             UFN5RBCA                 Back Account           0.0      0.0
# ...                                                         ...      ...
# 2026        O9S9VFIM                 G04-Books              0.0      0.0
#             XO7E9JLP                 G09-OF               800.0      0.0
#             YMJ3L6X6                 G08-B-2nd              0.0      0.0
#                                      G08-OF-2nd             0.0      0.0
#                                      G08-OF-3rd             0.0      0.0
#
#                                                     60_days  90_days  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account       0.0      0.0
#             LI5DFHZ5                 Back Account       0.0      0.0
#             QCNXOF71                 Back Account       0.0      0.0
#             TE11Z2LJ                 Back Account       0.0      0.0
#             UFN5RBCA                 Back Account       0.0      0.0
# ...                                                     ...      ...
# 2026        O9S9VFIM                 G04-Books          0.0      0.0
#             XO7E9JLP                 G09-OF             0.0      0.0
#             YMJ3L6X6                 G08-B-2nd          0.0      0.0
#                                      G08-OF-2nd         0.0      0.0
#                                      G08-OF-3rd         0.0      0.0
#
#                                                     120_days  150_days  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account        0.0       0.0
#             LI5DFHZ5                 Back Account        0.0       0.0
#             QCNXOF71                 Back Account        0.0       0.0
#             TE11Z2LJ                 Back Account        0.0       0.0
#             UFN5RBCA                 Back Account        0.0       0.0
# ...                                                      ...       ...
# 2026        O9S9VFIM                 G04-Books           0.0       0.0
#             XO7E9JLP                 G09-OF              0.0       0.0
#             YMJ3L6X6                 G08-B-2nd           0.0       0.0
#                                      G08-OF-2nd          0.0       0.0
#                                      G08-OF-3rd          0.0       0.0
#
#                                                     180_days  180_above  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account        0.0     9240.0
#             LI5DFHZ5                 Back Account        0.0     5650.0
#             QCNXOF71                 Back Account        0.0     3524.0
#             TE11Z2LJ                 Back Account        0.0     5886.0
#             UFN5RBCA                 Back Account        0.0     9831.0
# ...                                                      ...        ...
# 2026        O9S9VFIM                 G04-Books           0.0        0.0
#             XO7E9JLP                 G09-OF              0.0        0.0
#             YMJ3L6X6                 G08-B-2nd           0.0        0.0
#                                      G08-OF-2nd          0.0        0.0
#                                      G08-OF-3rd          0.0        0.0
#
#                                                     total_payments  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account           9240.0
#             LI5DFHZ5                 Back Account           5650.0
#             QCNXOF71                 Back Account           3524.0
#             TE11Z2LJ                 Back Account           5886.0
#             UFN5RBCA                 Back Account           9831.0
# ...                                                            ...
# 2026        O9S9VFIM                 G04-Books                 0.0
#             XO7E9JLP                 G09-OF                  800.0
#             YMJ3L6X6                 G08-B-2nd                 0.0
#                                      G08-OF-2nd                0.0
#                                      G08-OF-3rd                0.0
#
#                                                     adjusted_credit_amount  \
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account                   9240.0
#             LI5DFHZ5                 Back Account                   5650.0
#             QCNXOF71                 Back Account                   3524.0
#             TE11Z2LJ                 Back Account                   5886.0
#             UFN5RBCA                 Back Account                   9831.0
# ...                                                                    ...
# 2026        O9S9VFIM                 G04-Books                      5560.0
#             XO7E9JLP                 G09-OF                            0.0
#             YMJ3L6X6                 G08-B-2nd                      5200.0
#                                      G08-OF-2nd                     6267.0
#                                      G08-OF-3rd                     6266.0
#
#                                                     net_receivables
# school_year student_id_pseudonimized category_name
# 2016        CATF26JR                 Back Account               0.0
#             LI5DFHZ5                 Back Account               0.0
#             QCNXOF71                 Back Account               0.0
#             TE11Z2LJ                 Back Account               0.0
#             UFN5RBCA                 Back Account               0.0
# ...                                                             ...
# 2026        O9S9VFIM                 G04-Books               5560.0
#             XO7E9JLP                 G09-OF                     0.0
#             YMJ3L6X6                 G08-B-2nd               5200.0
#                                      G08-OF-2nd              6267.0
#                                      G08-OF-3rd              6266.0
#
# [9884 rows x 15 columns]

# %%
import pandas as pd

# Merge the two DataFrames on the keys
merged = df_truth.merge(
    df_test_opti,
    on=["school_year", "student_id_pseudonimized", "category_name"],
    suffixes=("_truth", "_test")
)

# Find rows where net_receivables differ
diff_rows = merged[merged["net_receivables_truth"] != merged["net_receivables_test"]]

diff_rows[['net_receivables_truth', 'net_receivables_test']]
# Out:
# Empty DataFrame
# Columns: [net_receivables_truth, net_receivables_test]
# Index: []

# %%
df_truth.reset_index(inplace=True)
